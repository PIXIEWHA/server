# %%
import shutil
import os
from glob import glob
import os.path, time

img_list = glob('/content/drive/MyDrive/Colab_Notebooks/code/dataset/minyoung_aug_noise5/images/*.jpg')
txt_list = glob('/content/drive/MyDrive/Colab_Notebooks/code/dataset/minyoung_aug_noise5/labels/*.txt')

txt_list1 = glob('/content/drive/MyDrive/Colab_Notebooks/code/dataset/minyounglee_label/*.txt')
txt_list2 = glob('/content/drive/MyDrive/Colab_Notebooks/code/dataset/export3/labels/*.txt')

# m_h = []

# for txt in txt_list1:
#   m_h.append(txt[70:-4])

# for txt in txt_list2:
#   m_h.append(txt[67:-4])

i_list = []
t_list = []
result = []
cnt = 0

for txt in txt_list:
    t_list.append(txt[79:-4])

for img in img_list:
    i_list.append(img[79:-4])

len_temp1=0
len_temp2=0

print(len(i_list))
print(len(t_list))
# print(len(m_h))

# for i in i_list:
#   if i not in m_h:
#     st = "/content/drive/MyDrive/Colab_Notebooks/code/dataset/haein_aug/images/"+i+".jpg"
#     len_temp1+=1
#     !cp $st /content/drive/MyDrive/Colab_Notebooks/code/dataset/export3/images/
  
# for t in t_list:
#   if t not in m_h:
#     st = "/content/drive/MyDrive/Colab_Notebooks/code/dataset/haein_aug/labels/"+t+".txt"
#     len_temp2+=1
#     !cp $st /content/drive/MyDrive/Colab_Notebooks/code/dataset/export3/labels/

# print(len_temp1)
# print(len_temp2)

# temp1 = glob('/content/drive/MyDrive/Colab_Notebooks/code/dataset/yhyeonjg/labels/*.txt')
# temp2 = glob('/content/drive/MyDrive/Colab_Notebooks/code/dataset/yhyeonjg/images/*.jpg')

# print(len(temp1))
# print(len(temp2))


for txt in t_list:
    if txt not in i_list:
      cnt+=1
      result.append(txt)

for i in result:
  print(i)
    
# print(len(img_list))
# print(cnt)
# Out:
# 3914
# 3915
# 174-5_cam01_dump02_place01_day_summer-mp4_31_frame_1860_jpg.rf.d187b97dfb52fe034bfe069125db39bb (1)

# %%
dou = 0
ans = []

for i in i_list:
    if i not in t_list:
      dou+=1
      ans.append(i)

for i in ans:
  print(i)

print(dou)
# Out:
# 0

# %%
temp1 = glob('/content/drive/MyDrive/Colab_Notebooks/code/dataset/yhyeonjg/labels/*.txt')
temp2 = glob('/content/drive/MyDrive/Colab_Notebooks/code/dataset/yhyeonjg/images/*.jpg')

print(len(temp1))
print(len(temp2))

temp1 = glob('/content/drive/MyDrive/Colab_Notebooks/code/dataset/export3/labels/*.txt')
temp2 = glob('/content/drive/MyDrive/Colab_Notebooks/code/dataset/export3/images/*.jpg')

print(len(temp1))
print(len(temp2))
# Out:
# 2000
# 2000
# 4000
# 4000
