# %%
import cv2
import os
import glob

video = 'outsidedoor_03'

# 디렉토리 경로
path_dir = 'C:/Users/yheo/OneDrive/바탕 화면/YOLO/'
folder_list = os.listdir(path_dir+video)

# 디렉토리 안 영상들 프레임 추출
for i in folder_list:
  file_list = glob.glob('./'+video+'/'+i+'/*.mp4')

  for j in file_list:
    vidcap = cv2.VideoCapture(j)
    
    print(j+" 영상 총 프레임 수 : %f" %vidcap.get(cv2.CAP_PROP_FRAME_COUNT))

    count = 1
    success = True

    while success:
      success, image = vidcap.read()
      
      # 프레임
      frame = int(vidcap.get(1))
      if(frame % 60 == 0):

        # 이미지 사이즈 변경
        # image = cv2.resize(image, (960, 540))
        
        title = './img/'+video+'/'+os.path.basename(j)+"_%d_frame_%d.jpg" % (count, frame)
        cv2.imwrite(title, image)
        print(title+" 저장")
    
        if cv2.waitKey(10) == 27:                    
          break
        
        count += 1
# Out:
# 영상 총 프레임 수 :727.000000
# 쓰레기 무단 투기 영상_1.mp4 saved image 1.jpg
# 쓰레기 무단 투기 영상_1.mp4 saved image 2.jpg
# 쓰레기 무단 투기 영상_1.mp4 saved image 3.jpg
# 쓰레기 무단 투기 영상_1.mp4 saved image 4.jpg
# 쓰레기 무단 투기 영상_1.mp4 saved image 5.jpg
# 쓰레기 무단 투기 영상_1.mp4 saved image 6.jpg
# 쓰레기 무단 투기 영상_1.mp4 saved image 7.jpg
# 쓰레기 무단 투기 영상_1.mp4 saved image 8.jpg
# 쓰레기 무단 투기 영상_1.mp4 saved image 9.jpg
# 쓰레기 무단 투기 영상_1.mp4 saved image 10.jpg
# 쓰레기 무단 투기 영상_1.mp4 saved image 11.jpg
# 쓰레기 무단 투기 영상_1.mp4 saved image 12.jpg
# 쓰레기 무단 투기 영상_1.mp4 saved image 13.jpg
# 쓰레기 무단 투기 영상_1.mp4 saved image 14.jpg
# 쓰레기 무단 투기 영상_1.mp4 saved image 15.jpg
# 쓰레기 무단 투기 영상_1.mp4 saved image 16.jpg
# 쓰레기 무단 투기 영상_1.mp4 saved image 17.jpg
# 쓰레기 무단 투기 영상_1.mp4 saved image 18.jpg
# 쓰레기 무단 투기 영상_1.mp4 saved image 19.jpg
# 쓰레기 무단 투기 영상_1.mp4 saved image 20.jpg
# 쓰레기 무단 투기 영상_1.mp4 saved image 21.jpg
# 쓰레기 무단 투기 영상_1.mp4 saved image 22.jpg
# 쓰레기 무단 투기 영상_1.mp4 saved image 23.jpg
# 쓰레기 무단 투기 영상_1.mp4 saved image 24.jpg
# 쓰레기 무단 투기 영상_1.mp4 saved image 25.jpg
# 쓰레기 무단 투기 영상_1.mp4 saved image 26.jpg
# 쓰레기 무단 투기 영상_1.mp4 saved image 27.jpg
# 쓰레기 무단 투기 영상_1.mp4 saved image 28.jpg
# 쓰레기 무단 투기 영상_1.mp4 saved image 29.jpg
# 쓰레기 무단 투기 영상_1.mp4 saved image 30.jpg
# 쓰레기 무단 투기 영상_1.mp4 saved image 31.jpg
# 쓰레기 무단 투기 영상_1.mp4 saved image 32.jpg
# 쓰레기 무단 투기 영상_1.mp4 saved image 33.jpg
# 쓰레기 무단 투기 영상_1.mp4 saved image 34.jpg
# 쓰레기 무단 투기 영상_1.mp4 saved image 35.jpg
# 쓰레기 무단 투기 영상_1.mp4 saved image 36.jpg
# 영상 총 프레임 수 :1892.000000
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 1.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 2.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 3.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 4.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 5.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 6.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 7.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 8.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 9.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 10.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 11.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 12.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 13.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 14.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 15.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 16.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 17.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 18.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 19.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 20.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 21.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 22.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 23.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 24.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 25.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 26.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 27.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 28.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 29.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 30.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 31.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 32.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 33.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 34.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 35.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 36.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 37.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 38.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 39.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 40.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 41.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 42.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 43.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 44.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 45.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 46.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 47.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 48.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 49.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 50.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 51.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 52.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 53.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 54.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 55.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 56.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 57.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 58.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 59.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 60.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 61.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 62.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 63.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 64.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 65.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 66.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 67.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 68.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 69.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 70.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 71.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 72.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 73.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 74.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 75.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 76.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 77.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 78.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 79.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 80.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 81.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 82.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 83.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 84.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 85.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 86.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 87.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 88.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 89.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 90.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 91.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 92.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 93.jpg
# Singjamei Super Market Illegal Waste Dumping Footage CCTV Camera 1.mp4 saved image 94.jpg
# 영상 총 프레임 수 :632.000000
# illegal trash dumping detection (test1)_1.mp4 saved image 1.jpg
# illegal trash dumping detection (test1)_1.mp4 saved image 2.jpg
# illegal trash dumping detection (test1)_1.mp4 saved image 3.jpg
# illegal trash dumping detection (test1)_1.mp4 saved image 4.jpg
# illegal trash dumping detection (test1)_1.mp4 saved image 5.jpg
# illegal trash dumping detection (test1)_1.mp4 saved image 6.jpg
# illegal trash dumping detection (test1)_1.mp4 saved image 7.jpg
# illegal trash dumping detection (test1)_1.mp4 saved image 8.jpg
# illegal trash dumping detection (test1)_1.mp4 saved image 9.jpg
# illegal trash dumping detection (test1)_1.mp4 saved image 10.jpg
# illegal trash dumping detection (test1)_1.mp4 saved image 11.jpg
# illegal trash dumping detection (test1)_1.mp4 saved image 12.jpg
# illegal trash dumping detection (test1)_1.mp4 saved image 13.jpg
# illegal trash dumping detection (test1)_1.mp4 saved image 14.jpg
# illegal trash dumping detection (test1)_1.mp4 saved image 15.jpg
# illegal trash dumping detection (test1)_1.mp4 saved image 16.jpg
# illegal trash dumping detection (test1)_1.mp4 saved image 17.jpg
# illegal trash dumping detection (test1)_1.mp4 saved image 18.jpg
# illegal trash dumping detection (test1)_1.mp4 saved image 19.jpg
# illegal trash dumping detection (test1)_1.mp4 saved image 20.jpg
# illegal trash dumping detection (test1)_1.mp4 saved image 21.jpg
# illegal trash dumping detection (test1)_1.mp4 saved image 22.jpg
# illegal trash dumping detection (test1)_1.mp4 saved image 23.jpg
# illegal trash dumping detection (test1)_1.mp4 saved image 24.jpg
# illegal trash dumping detection (test1)_1.mp4 saved image 25.jpg
# illegal trash dumping detection (test1)_1.mp4 saved image 26.jpg
# illegal trash dumping detection (test1)_1.mp4 saved image 27.jpg
# illegal trash dumping detection (test1)_1.mp4 saved image 28.jpg
# illegal trash dumping detection (test1)_1.mp4 saved image 29.jpg
# illegal trash dumping detection (test1)_1.mp4 saved image 30.jpg
# illegal trash dumping detection (test1)_1.mp4 saved image 31.jpg
